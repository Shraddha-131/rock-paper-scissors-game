# %%
import random

computer = random.choice(["a","b","c"])
youstr=(input("enter your choice"))
yourdict={"rock":"a","paper":"b","scissor":"c"}
reversedict={"a":"rock","b":"paper","c":"scissor"}
you=yourdict[youstr]

print(f"your choice {reversedict[you]}\ncomputer choice {reversedict[computer]}")

if(computer==you):
  print("its a draw")

else:
   if(computer=="a" and you=="b"):
      print("you win")
   elif(computer=="b" and you=="a"):
      print("you lose")
   elif(computer=="a" and you=="c"):
      print("you lose")
   elif(computer=="b" and you=="c"):
      print("you win")
   if(computer=="c" and you=="b"):
      print("you lose")
   if(computer=="c" and you=="a"):
      print("you win")
# Out:
# enter your choice paper
# your choice paper
# computer choice rock
# you win
